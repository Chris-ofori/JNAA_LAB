# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cf
import cartopy.io.shapereader as shapereader

from pathlib import Path

# %%
#location_path = ('data')

# %%
drr = np.genfromtxt('C:/Users/ofo/Desktop/Intership/OneQuantum-Ghana-main/data/rr_temp_rh_24_30May21.csv', delimiter=',', skip_header=1, usecols=[0,1,2,3,4,5])
apt = np.genfromtxt('C:/Users/ofo/Desktop/Intership/OneQuantum-Ghana-main/data/rr_temp_rh_24_30May21.csv', delimiter=',', skip_header=1, usecols=[:])
lat = drr[:,0]
lon = drr[:,1]
rr = drr[:,2]
tn = drr[:,3]
tx = drr[:,4]
rh = drr[:,5]

# %%
lon
# Out:
# array([-0.280419 , -0.380419 , -0.280419 , ..., -2.0804191, -2.0304191,
#        -1.980419 ])

# %%
drr
# Out:
# array([[11.1637506, -0.280419 ,  4.9334192, 36.2483521, 26.2838516,
#         48.000679 ],
#        [11.1137514, -0.380419 ,  7.9720955, 36.4342842, 26.4156952,
#         47.3204727],
#        [11.1137514, -0.280419 ,  4.4984193, 36.2509613, 26.2900066,
#         47.9930153],
#        ...,
#        [ 4.763751 , -2.0804191,  7.5646267, 31.3550129, 25.5790215,
#         75.7629776],
#        [ 4.763751 , -2.0304191,  9.4561901, 31.5191727, 25.6382923,
#         75.3197632],
#        [ 4.763751 , -1.980419 , 11.9670143, 31.6822319, 25.712389 ,
#         74.9625397]])

# %%
lat
# Out:
# array([11.1637506, 11.1137514, 11.1137514, ...,  4.763751 ,  4.763751 ,
#         4.763751 ])

# %%
rr
# Out:
# array([ 4.9334192,  7.9720955,  4.4984193, ...,  7.5646267,  9.4561901,
#        11.9670143])

# %%
tn
# Out:
# array([36.2483521, 36.4342842, 36.2509613, ..., 31.3550129, 31.5191727,
#        31.6822319])

# %%
tx
# Out:
# array([26.2838516, 26.4156952, 26.2900066, ..., 25.5790215, 25.6382923,
#        25.712389 ])

# %%
rh
# Out:
# array([48.000679 , 47.3204727, 47.9930153, ..., 75.7629776, 75.3197632,
#        74.9625397])

# %%
shp_path = ('C:/Users/ofo/Desktop/Intership/OneQuantum-Ghana-main/data/gh_shp/gh_wgs16dregions.shp')
adm1_shapes = list(shapereader.Reader(str(shp_path)).geometries())

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([-4,2,4,12], crs=ccrs.PlateCarree())

ax.add_geometries(adm1_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)


#ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cf.LAKES, edgecolor='black')

ax.set(title='Total Rainfall')
splot = ax.scatter(lon,lat,25,c=rr, cmap=cm.jet_r, alpha=1)
fig.colorbar(splot,label="Rainfall (mm)", orientation="vertical", extend='both')

# %%
plt.scatter(lat,lon,200,c=rr)

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([-4,2,4,12], crs=ccrs.PlateCarree())

ax.add_geometries(adm1_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)


ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cf.LAKES, edgecolor='black')

ax.set(title='ADM Rainfall distribution - 2020')
splot = ax.scatter(lon,lat,200,c=tx, cmap=cm.jet, alpha=1)
fig.colorbar(splot,label="Weakly_mean_daily_maximum_temp ", orientation="vertical", extend='both')

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([-4,2,4,12], crs=ccrs.PlateCarree())

ax.add_geometries(adm1_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)


ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cf.LAKES, edgecolor='black')
#ax.add_coastline()
ax.set(title='Mean Relative Humidity')
splot = ax.scatter(lon,lat,200,c=rh, cmap=cm.jet_r, alpha=1)
fig.colorbar(splot,label="mean relative humidity ", orientation="vertical", extend='both')

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([-4,2,4,12], crs=ccrs.PlateCarree())

ax.add_geometries(adm1_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)


ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cf.LAKES, edgecolor='black')
#ax.add_coastline()
ax.set(title='Weakly mean Daily Minimum temperature')
splot = ax.scatter(lon,lat,200,c=tn, cmap=cm.jet, alpha=1)
fig.colorbar(splot,label="Weakly Mean Daily Minimum Temp ", orientation="vertical", extend='both')
